# %% [markdown]
# <a href="https://colab.research.google.com/github/Jatansahu/woc5.0-ml-weather-prediction-case-study-jatan-sahu/blob/main/Checkpoint_3_PROJECT_(1).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Youtube-Influencer-Analysis-case-study**-

# %% [markdown]
# 1) Reading the above CSV file in google colab using the pandas’ library and converting it into data frames.

# %%
import pandas as pd

# %%
import pandas as pd
df1=pd.read_csv("/Youtube Influencer Analysis - Updated.csv",encoding='mac_roman')
df1
# Out:
#                                             Video Link Video Views  \
# 0          https://www.youtube.com/watch?v=_0fUOJ55gis     146,059
# 1          https://www.youtube.com/watch?v=_70MSLPRfZI     231,969
# 2    https://www.youtube.com/watch?v=_8gfCdt3H00&t=87s         878
# 3          https://www.youtube.com/watch?v=_CkFNJgKsFs       9,965
# 4          https://www.youtube.com/watch?v=_GFkHA5EZdE  39,780,561
# ..                                                 ...         ...
# 900        https://www.youtube.com/watch?v=GS18WawA-t0       6,892
# 901        https://www.youtube.com/watch?v=_tc_APkjH2Q      16,554
# 902        https://www.youtube.com/watch?v=Xfj4osSYfhU      32,798
# 903        https://www.youtube.com/watch?v=mGEHqwVz0eI       1,503
# 904        https://www.youtube.com/watch?v=UGATpt0I4vA     429,966
#
#                                            Video Title  \
# 0      Samse - Didupe Off-road Royal Enfield Himalayan
# ...

# %%
df1.head()
# Out:
#                                           Video Link Video Views  \
# 0        https://www.youtube.com/watch?v=_0fUOJ55gis     146,059
# 1        https://www.youtube.com/watch?v=_70MSLPRfZI     231,969
# 2  https://www.youtube.com/watch?v=_8gfCdt3H00&t=87s         878
# 3        https://www.youtube.com/watch?v=_CkFNJgKsFs       9,965
# 4        https://www.youtube.com/watch?v=_GFkHA5EZdE  39,780,561
#
#                                          Video Title  \
# 0    Samse - Didupe Off-road Royal Enfield Himalayan
# 1                           Bhoom Baddhal Web Series
# 2  Customer Psychology, Four Views Of Consumer De...
# 3     Top countries with proven natural gas reserves
# 4                     73 Questions With Selena Gomez
#
#                                          Channel URL Creator Name  \
# 0                https://www.youtube.com/c/sriharick   srihari ck
# 1         https://www.youtube.com/c/ChaibisketTelugu  Chai Bisket
# ...

# %%
df1.describe()
# Out:
#         No of Likes    Hashtags  Maximum Quality of the Video  \
# count  9.040000e+02  905.000000                    905.000000
# mean   5.840101e+05    1.030939                   1227.712707
# std    2.959309e+06    1.835350                    419.254719
# min    0.000000e+00    0.000000                    240.000000
# 25%    5.475000e+03    0.000000                   1080.000000
# 50%    3.250000e+04    0.000000                   1080.000000
# 75%    1.845000e+05    2.000000                   1080.000000
# max    4.900000e+07   28.000000                   2160.000000
#
#        No of Videos the Channel  No of Playlist  \
# count                905.000000      896.000000
# mean                4962.866298       82.246652
# std                24193.140397      446.041267
# min                    1.000000        0.000000
# 25%                  150.000000        6.000000
# 50%                  389.000000       16.000000
# 75%                 1393.000000       47.250000
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 905 entries, 0 to 904
# Data columns (total 24 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   Video Link                             905 non-null    object
#  1   Video Views                            905 non-null    object
#  2   Video Title                            905 non-null    object
#  3   Channel URL                            905 non-null    object
#  4   Creator Name                           894 non-null    object
#  5   Creator Gender                         591 non-null    object
#  6   Total Channel Subcribers               905 non-null    object
#  7   Total Chanel Views                     905 non-null    object
#  8   Duration of Video                      905 non-null    object
#  9   Duration in Seconds                    905 non-null    object
# ...

# %% [markdown]
# 2) How many values are missing for each column and try dropping or replacing NULL values using appropriate pandas’ function.

# %%
#Number of missing values
df2=df1.isnull().sum()
df2
# Out:
# Video Link                                 0
# Video Views                                0
# Video Title                                0
# Channel URL                                0
# Creator Name                              11
# Creator Gender                           314
# Total Channel Subcribers                   0
# Total Chanel Views                         0
# Duration of Video                          0
# Duration in Seconds                        0
# Date of Video Upload                       0
# No of Likes                                1
# Language of the Video                     21
# Subtitle                                   1
# Video Description                          0
# Hashtags                                   0
# No of Comments                             0
# Date of the Last Comment                  24
# Maximum Quality of the Video               0
# No of Videos the Channel                   0
# No of Playlist                             9
# ...

# %% [markdown]
# **REMOVING UNWANTED ERROR**

# %%
#CHANGING  COLUMN to lower case
df1.columns = df1.columns.str.lower()
#Replacing spaces to "_"
df1.columns = df1.columns.str.replace(' ','_')

# %%
df1.head()
# Out:
#                                           video_link video_views  \
# 0        https://www.youtube.com/watch?v=_0fUOJ55gis     146,059
# 1        https://www.youtube.com/watch?v=_70MSLPRfZI     231,969
# 2  https://www.youtube.com/watch?v=_8gfCdt3H00&t=87s         878
# 3        https://www.youtube.com/watch?v=_CkFNJgKsFs       9,965
# 4        https://www.youtube.com/watch?v=_GFkHA5EZdE  39,780,561
#
#                                          video_title  \
# 0    Samse - Didupe Off-road Royal Enfield Himalayan
# 1                           Bhoom Baddhal Web Series
# 2  Customer Psychology, Four Views Of Consumer De...
# 3     Top countries with proven natural gas reserves
# 4                     73 Questions With Selena Gomez
#
#                                          channel_url creator_name  \
# 0                https://www.youtube.com/c/sriharick   srihari ck
# 1         https://www.youtube.com/c/ChaibisketTelugu  Chai Bisket
# ...

# %%
df1["video_views"]=df1["video_views"].astype(str)

# %%
#DROPING NaN value row except Creator Gender,will drop this column

#df3=df1.dropna(subset=["Creator Name","No of Likes","Language of the Video","Date of the Last Comment","No of Playlist"])

#df3

# %% [markdown]
# 3) Drop the columns which are irrelevant features to feed into our model.

# %%
df1.creator_gender.value_counts()
# Out:
# Male       494
# Female      78
# Company     19
# Name: creator_gender, dtype: int64

# %%
df1.creator_gender.isnull()

# %%
df4=df3.drop(columns=['Video Link','Channel URL','Intern Who Collected the Data','Creator Gender'])
df4
# Out:
#     Video Views                                        Video Title  \
# 0       146,059    Samse - Didupe Off-road Royal Enfield Himalayan
# 1       231,969                           Bhoom Baddhal Web Series
# 3         9,965     Top countries with proven natural gas reserves
# 4    39,780,561                     73 Questions With Selena Gomez
# 5       257,334                     HERO - Baananchige Oduva Baara
# ..          ...                                                ...
# 900       6,892  Calming mashup of Islamic Nasheed 2022 | Isami...
# 901      16,554                           Amchi Nawayat Mehfil hee
# 902      32,798                                      Aas ge Kaagaz
# 903       1,503  Anjuman Tarana by ABHS Students | Anjuman Anju...
# 904     429,966  Jhulan Goswami Final Over in ODIs | ENG vs IND...
#
#              Creator Name Total Channel Subcribers Total Chanel Views  \
# 0              srihari ck                    40200            7964284
# ...

# %% [markdown]
# 4) Some columns are not statistical data but in the form of strings. It Is difficult for our model to learn when the data is in form of strings. Your task is to encode these strings using proper encoding techniques.

# %%
df4.dtypes

#OBJECT - MIXED NUMBER AND STRING 
#FLOAT564 - WITH DECIMAL
#INT64 - 	NUMERIC CHARACTER
# Out:
# Video Views                               object
# Video Title                               object
# Creator Name                              object
# Total Channel Subcribers                  object
# Total Chanel Views                        object
# Duration of Video                         object
# Duration in Seconds                       object
# Date of Video Upload                      object
# No of Likes                              float64
# Language of the Video                     object
# Subtitle                                  object
# Video Description                         object
# Hashtags                                   int64
# No of Comments                            object
# Date of the Last Comment                  object
# Maximum Quality of the Video               int64
# No of Videos the Channel                   int64
# No of Playlist                           float64
# Premiered or Not                          object
# ...

# %%
pd.get_dummies(df4, columns=['Subtitle','Video Description','Premiered or Not'])
# Out:
#     Video Views                                        Video Title  \
# 0       146,059    Samse - Didupe Off-road Royal Enfield Himalayan
# 1       231,969                           Bhoom Baddhal Web Series
# 3         9,965     Top countries with proven natural gas reserves
# 4    39,780,561                     73 Questions With Selena Gomez
# 5       257,334                     HERO - Baananchige Oduva Baara
# ..          ...                                                ...
# 900       6,892  Calming mashup of Islamic Nasheed 2022 | Isami...
# 901      16,554                           Amchi Nawayat Mehfil hee
# 902      32,798                                      Aas ge Kaagaz
# 903       1,503  Anjuman Tarana by ABHS Students | Anjuman Anju...
# 904     429,966  Jhulan Goswami Final Over in ODIs | ENG vs IND...
#
#              Creator Name Total Channel Subcribers Total Chanel Views  \
# 0              srihari ck                    40200            7964284
# ...
